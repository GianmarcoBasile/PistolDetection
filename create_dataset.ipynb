# %%
# %pip install -r requirements.txt --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

HOME = os.getcwd()

if "Dataset" not in os.listdir(HOME):
  try:
    os.mkdir(HOME + "/Dataset")
  except FileExistsError:
    pass

# %%
Dataset = HOME + "/Dataset"

if "Images" not in os.listdir(Dataset):
  try:
    os.mkdir(Dataset + "/fasterrcnn")
  except FileExistsError:
    pass

images_folder = Dataset + "/fasterrcnn"

# %%
from dotenv import load_dotenv

load_dotenv()

roboflow_api_key = os.getenv("ROBOFLOW_API_KEY")

# %%
from roboflow import Roboflow

os.chdir(images_folder)
from roboflow import Roboflow
rf = Roboflow(api_key=roboflow_api_key)
project = rf.workspace("amir-guliamov-phqcg").project("gun-1ri4p")
version = project.version(3)
dataset = version.download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to gun-3 in coco:: 100%|██████████| 8396/8396 [00:03<00:00, 2201.21it/s]

# %%
import shutil

print(os.listdir(images_folder))
if "gun-3" in os.listdir(images_folder) and "train" in os.listdir(images_folder+"/gun-3") and "valid" in os.listdir(images_folder+"/gun-3"):
  shutil.move(images_folder + "/gun-3/train", images_folder)
  shutil.move(images_folder + "/gun-3/valid", images_folder)
  shutil.rmtree(images_folder + "/gun-3/test")
  shutil.rmtree(images_folder + "/gun-3")
# Out:
# ['gun-3']
