# %%
# %pip install -r requirements.txt --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: albumentations in /home/gianmarco/.local/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.0.5)
# Requirement already satisfied: matplotlib in /usr/lib/python3/dist-packages (from -r requirements.txt (line 2)) (3.6.3)
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (from -r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: pandas in /home/gianmarco/.local/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (2.2.3)
# Requirement already satisfied: pillow in /usr/lib/python3/dist-packages (from -r requirements.txt (line 5)) (10.2.0)
# Requirement already satisfied: python-dotenv in /home/gianmarco/.local/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (1.0.1)
# Requirement already satisfied: roboflow in /home/gianmarco/.local/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (1.1.57)
# Requirement already satisfied: torch==2.2.0+cu118 in /home/gianmarco/.local/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (2.2.0+cu118)
# Requirement already satisfied: torchvision==0.17.0+cu118 in /home/gianmarco/.local/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (0.17.0+cu118)
# Requirement already satisfied: torchaudio==2.2.0+cu118 in /home/gianmarco/.local/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (2.2.0+cu118)
# Requirement already satisfied: pycocotools in /home/gianmarco/.local/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (2.0.8)
# Requirement already satisfied: onnx in /home/gianmarco/.local/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (1.17.0)
# Requirement already satisfied: onnxruntime in /home/gianmarco/.local/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (1.21.0)
# Requirement already satisfied: seaborn in /home/gianmarco/.local/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (0.13.2)
# Requirement already satisfied: dotenv in /home/gianmarco/.local/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (0.9.9)
# Requirement already satisfied: filelock in /home/gianmarco/.local/lib/python3.12/site-packages (from torch==2.2.0+cu118->-r requirements.txt (line 8)) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/gianmarco/.local/lib/python3.12/site-packages (from torch==2.2.0+cu118->-r requirements.txt (line 8)) (4.12.2)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch==2.2.0+cu118->-r requirements.txt (line 8)) (1.12)
# Requirement already satisfied: networkx in /home/gianmarco/.local/lib/python3.12/site-packages (from torch==2.2.0+cu118->-r requirements.txt (line 8)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch==2.2.0+cu118->-r requirements.txt (line 8)) (3.1.2)
# Requirement already satisfied: fsspec in /home/gianmarco/.local/lib/python3.12/site-packages (from torch==2.2.0+cu118->-r requirements.txt (line 8)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home/gianmarco/.local/lib/python3.12/site-packages (from torch==2.2.0+cu118->-r requirements.txt (line 8)) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home/gianmarco/.local/lib/python3.12/site-packages (from torch==2.2.0+cu118->-r requirements.txt (line 8)) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home/gianmarco/.local/lib/python3.12/site-packages (from torch==2.2.0+cu118->-r requirements.txt (line 8)) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==8.7.0.84 in /home/gianmarco/.local/lib/python3.12/site-packages (from torch==2.2.0+cu118->-r requirements.txt (line 8)) (8.7.0.84)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home/gianmarco/.local/lib/python3.12/site-packages (from torch==2.2.0+cu118->-r requirements.txt (line 8)) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/gianmarco/.local/lib/python3.12/site-packages (from torch==2.2.0+cu118->-r requirements.txt (line 8)) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home/gianmarco/.local/lib/python3.12/site-packages (from torch==2.2.0+cu118->-r requirements.txt (line 8)) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home/gianmarco/.local/lib/python3.12/site-packages (from torch==2.2.0+cu118->-r requirements.txt (line 8)) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home/gianmarco/.local/lib/python3.12/site-packages (from torch==2.2.0+cu118->-r requirements.txt (line 8)) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.19.3 in /home/gianmarco/.local/lib/python3.12/site-packages (from torch==2.2.0+cu118->-r requirements.txt (line 8)) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home/gianmarco/.local/lib/python3.12/site-packages (from torch==2.2.0+cu118->-r requirements.txt (line 8)) (11.8.86)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from torchvision==0.17.0+cu118->-r requirements.txt (line 9)) (2.31.0)
# Requirement already satisfied: scipy>=1.10.0 in /usr/lib/python3/dist-packages (from albumentations->-r requirements.txt (line 1)) (1.11.4)
# Requirement already satisfied: PyYAML in /usr/lib/python3/dist-packages (from albumentations->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: pydantic>=2.9.2 in /home/gianmarco/.local/lib/python3.12/site-packages (from albumentations->-r requirements.txt (line 1)) (2.10.6)
# Requirement already satisfied: albucore==0.0.23 in /home/gianmarco/.local/lib/python3.12/site-packages (from albumentations->-r requirements.txt (line 1)) (0.0.23)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /home/gianmarco/.local/lib/python3.12/site-packages (from albumentations->-r requirements.txt (line 1)) (4.10.0.84)
# Requirement already satisfied: stringzilla>=3.10.4 in /home/gianmarco/.local/lib/python3.12/site-packages (from albucore==0.0.23->albumentations->-r requirements.txt (line 1)) (3.12.3)
# Requirement already satisfied: simsimd>=5.9.2 in /home/gianmarco/.local/lib/python3.12/site-packages (from albucore==0.0.23->albumentations->-r requirements.txt (line 1)) (6.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3/dist-packages (from pandas->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->-r requirements.txt (line 4)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/gianmarco/.local/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 4)) (2025.1)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from roboflow->-r requirements.txt (line 7)) (2023.11.17)
# Requirement already satisfied: idna==3.7 in /home/gianmarco/.local/lib/python3.12/site-packages (from roboflow->-r requirements.txt (line 7)) (3.7)
# Requirement already satisfied: cycler in /usr/lib/python3/dist-packages (from roboflow->-r requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/gianmarco/.local/lib/python3.12/site-packages (from roboflow->-r requirements.txt (line 7)) (1.4.8)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from roboflow->-r requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/lib/python3/dist-packages (from roboflow->-r requirements.txt (line 7)) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /home/gianmarco/.local/lib/python3.12/site-packages (from roboflow->-r requirements.txt (line 7)) (4.67.1)
# Requirement already satisfied: requests-toolbelt in /home/gianmarco/.local/lib/python3.12/site-packages (from roboflow->-r requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: filetype in /home/gianmarco/.local/lib/python3.12/site-packages (from roboflow->-r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: protobuf>=3.20.2 in /home/gianmarco/.local/lib/python3.12/site-packages (from onnx->-r requirements.txt (line 12)) (6.30.0)
# Requirement already satisfied: coloredlogs in /home/gianmarco/.local/lib/python3.12/site-packages (from onnxruntime->-r requirements.txt (line 13)) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/gianmarco/.local/lib/python3.12/site-packages (from onnxruntime->-r requirements.txt (line 13)) (25.2.10)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from onnxruntime->-r requirements.txt (line 13)) (24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/gianmarco/.local/lib/python3.12/site-packages (from pydantic>=2.9.2->albumentations->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/gianmarco/.local/lib/python3.12/site-packages (from pydantic>=2.9.2->albumentations->-r requirements.txt (line 1)) (2.27.2)
# Requirement already satisfied: humanfriendly>=9.1 in /home/gianmarco/.local/lib/python3.12/site-packages (from coloredlogs->onnxruntime->-r requirements.txt (line 13)) (10.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

HOME = os.getcwd()

if "Dataset" not in os.listdir(HOME):
  try:
    os.mkdir(HOME + "/Dataset")
  except FileExistsError:
    pass

# %%
Dataset = HOME + "/Dataset"

if "Images" not in os.listdir(Dataset):
  try:
    os.mkdir(Dataset + "/Images")
  except FileExistsError:
    pass

images_folder = Dataset + "/Images"

# %%
from dotenv import load_dotenv

load_dotenv()

roboflow_api_key = os.getenv("ROBOFLOW_API_KEY")

# %%
from roboflow import Roboflow

os.chdir(images_folder)
rf = Roboflow(api_key=roboflow_api_key)
project = rf.workspace("joseph-nelson").project("pistols")
version = project.version(1)
dataset = version.download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Pistols-1 to coco:: 100%|██████████| 60856/60856 [00:04<00:00, 12684.27it/s]
# Extracting Dataset Version Zip to Pistols-1 in coco:: 100%|██████████| 2974/2974 [00:00<00:00, 20426.28it/s]

# %%
import shutil

export_folder = images_folder + "/Pistols-1/export"
images = os.listdir(export_folder)
os.chdir(export_folder)

for i in range(0, len(images)):
    shutil.move(images[i], images_folder)
os.chdir(HOME)
shutil.rmtree(images_folder + "/Pistols-1")
